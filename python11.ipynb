# %% [markdown]
# <a href="https://colab.research.google.com/github/dinniprakash/Python-Record/blob/main/python11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 11.Inheritance: By using the concept of inheritance write a python program to find the area of triangle, circle and rectangle.

# %%
import math
def area_of_triangle(base, height):
    return 0.5 * base * height
def area_of_circle(radius):
    return math.pi * radius ** 2
def area_of_rectangle(length, width):
    return length * width
print("Area of triangle:", area_of_triangle(5, 10))
print("Area of circle:", area_of_circle(7))
print("Area of rectangle:", area_of_rectangle(4, 8))
# Out:
# Area of triangle: 25.0
# Area of circle: 153.93804002589985
# Area of rectangle: 32
